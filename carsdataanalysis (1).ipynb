# %%
#import all libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
#load the dataset using pandas read_csv () function
car=pd.read_csv("/content/gdrive/MyDrive/DATA SCIENCE/DATASETS/cars.csv")
cars=pd.DataFrame(car)
cars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#mean
sum=cars["mpg"].sum(axis=0)
count=cars["mpg"].count()
mean=sum/count
mean
# Out:
# 20.090625000000003

# %%
cars["mpg"].mean()
# Out:
# 20.090625000000003

# %%
#median
cars["mpg"].median()
# Out:
# 19.2

# %%
sort=cars["mpg"].sort_values()

count= sort.count()
print(sort)
if sort.count()%2==0:
   n=count/2
   print(cars.loc[n])
# Out:
# 15    10.4
# 14    10.4
# 23    13.3
# 6     14.3
# 16    14.7
# 30    15.0
# 13    15.2
# 22    15.2
# 21    15.5
# 28    15.8
# 11    16.4
# 12    17.3
# 10    17.8
# 5     18.1
# 4     18.7
# 9     19.2
# 24    19.2
# 29    19.7
# 0     21.0
# 1     21.0
# 3     21.4
# 31    21.4
# 20    21.5
# 8     22.8
# 2     22.8
# 7     24.4
# 26    26.0
# 25    27.3
# 27    30.4
# 18    30.4
# 17    32.4
# 19    33.9
# Name: mpg, dtype: float64
# Unnamed: 0    Chrysler Imperial
# mpg                        14.7
# cyl                           8
# disp                      440.0
# hp                          230
# drat                       3.23
# wt                        5.345
# qsec                      17.42
# vs                            0
# am                            0
# gear                          3
# carb                          4
# Name: 16, dtype: object

# %%
#display the head of the dataset usig head() function
car.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
car.tail(5)
# Out:
#         Unnamed: 0   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
#print summary statistics of the dataset using describe() function
car.describe(include="all")
# Out:
#        Unnamed: 0        mpg        cyl        disp          hp       drat  \
# count          32  32.000000  32.000000   32.000000   32.000000  32.000000
# unique         32        NaN        NaN         NaN         NaN        NaN
# top     Mazda RX4        NaN        NaN         NaN         NaN        NaN
# freq            1        NaN        NaN         NaN         NaN        NaN
# mean          NaN  20.090625   6.187500  230.721875  146.687500   3.596563
# std           NaN   6.026948   1.785922  123.938694   68.562868   0.534679
# min           NaN  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%           NaN  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%           NaN  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%           NaN  22.800000   8.000000  326.000000  180.000000   3.920000
# max           NaN  33.900000   8.000000  472.000000  335.000000   4.930000
#
# ...

# %%
#plot a histogram for all variables
car.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'mpg'}>, <Axes: title={'center': 'cyl'}>,
#         <Axes: title={'center': 'disp'}>],
#        [<Axes: title={'center': 'hp'}>, <Axes: title={'center': 'drat'}>,
#         <Axes: title={'center': 'wt'}>],
#        [<Axes: title={'center': 'qsec'}>, <Axes: title={'center': 'vs'}>,
#         <Axes: title={'center': 'am'}>],
#        [<Axes: title={'center': 'gear'}>,
#         <Axes: title={'center': 'carb'}>, <Axes: >]], dtype=object)

# %%
#boxplot to visualize relationship between hp and gear
sns.boxplot(x="hp",y="gear",data=car)
# Out:
# <Axes: xlabel='hp', ylabel='gear'>

# %%
#build a pair plot using the seaborn library
sns.pairplot(car)

# %%
#drop irreleavant coloumns from yhe dataset using drop() function
car=car.drop(["am","gear"],axis=1)
car.head(5)
# Out:
#           Unnamed: 0   disp   hp     wt   qsec  vs  carb
# 0          Mazda RX4  160.0  110  2.620  16.46   0     4
# 1      Mazda RX4 Wag  160.0  110  2.875  17.02   0     4
# 2         Datsun 710  108.0   93  2.320  18.61   1     1
# 3     Hornet 4 Drive  258.0  110  3.215  19.44   1     1
# 4  Hornet Sportabout  360.0  175  3.440  17.02   0     2

# %%
#Renaming the coloumn
car=car.rename(columns={"hp":"horse power"})
car.head(5)
# Out:
#           Unnamed: 0   disp  horse power     wt   qsec  vs  carb
# 0          Mazda RX4  160.0          110  2.620  16.46   0     4
# 1      Mazda RX4 Wag  160.0          110  2.875  17.02   0     4
# 2         Datsun 710  108.0           93  2.320  18.61   1     1
# 3     Hornet 4 Drive  258.0          110  3.215  19.44   1     1
# 4  Hornet Sportabout  360.0          175  3.440  17.02   0     2

# %%
duplicate_row_car=car[car.duplicated()]
print("number of duplicate rows:",duplicate_row_car.shape)
# Out:
# number of duplicate rows: (0, 12)

# %%
car.count()
# Out:
# Unnamed: 0    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          32
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
car=car.drop_duplicates()
car.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
print(car.isnull().sum())
# Out:
# Unnamed: 0    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
car=car.dropna()
car.count()
# Out:
# Unnamed: 0    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          32
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
car["cyl"].value_counts().nlargest(40).plot(kind="bar",figsize=(10,5))
plt.title("number of car by maker")
plt.ylabel("number of cars")
plt.xlabel("make")
# Out:
# Text(0.5, 0, 'make')

# %%
plt.figure(figsize=(10,10))
c=car.corr()
sns.heatmap(c,cmap="icefire_r",annot=True)
c
# Out:
# <ipython-input-34-d58877705d31>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=car.corr()
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# ...
